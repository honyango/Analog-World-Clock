# %% [markdown]
# <a href="https://colab.research.google.com/github/honyango/Analog-World-Clock/blob/master/Untitled38.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# Given data
x = [2, 5, 1, 3, 4, 1, 5, 3, 4, 2]
y = [50, 57, 41, 54, 54, 38, 63, 48, 59, 49]

# Create scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(x, y, color='blue', edgecolor='black')
plt.title('TV Commercials vs. Store Sales')
plt.xlabel('Number of TV Commercials (x)')
plt.ylabel('Store Sales (y)')
plt.grid(True)
plt.show()
