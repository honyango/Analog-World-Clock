# %% [markdown]
# <a href="https://colab.research.google.com/github/honyango/Analog-World-Clock/blob/master/Another_copy_of_Untitled39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.stats import pearsonr

# Define the variables x and y with some sample data
x = np.array([2,5,1,3,4,1,5,3,4,2])
y = np.array([50,57,41,54,54,38,63,48,59,49])

# Calculate Pearson correlation
correlation, p_value = pearsonr(x, y)

print(f"Pearson correlation coefficient: {correlation:.3f}")
print(f"P-value: {p_value:.3f}")
# Out:
# Pearson correlation coefficient: 0.920
# P-value: 0.000

# %% [markdown]
# Linear Regression Analysis in Python

# %%
import numpy as np
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression

# Define the variables x and y with some sample data
x = np.array([2,5,1,3,4,1,5,3,4,2])
y = np.array([50,57,41,54,54,38,63,48,59,49])

# Calculate Pearson correlation
correlation, p_value = pearsonr(x, y)

print(f"Pearson correlation coefficient: {correlation:.3f}")
print(f"P-value: {p_value:.3f}")

# Linear Regression Analysis in Python
# Reshape x for sklearn
x_reshaped = np.array(x).reshape(-1, 1)
y_array = np.array(y)

# Create model and fit
model = LinearRegression()
model.fit(x_reshaped, y_array)

# Get parameters
slope = model.coef_[0]
intercept = model.intercept_

print(f"Regression equation: y = {slope:.2f}x + {intercept:.2f}")
# Out:
# Pearson correlation coefficient: 0.920
# P-value: 0.000
# Regression equation: y = 4.80x + 36.90

# %% [markdown]
# PLot Regression Line

# %%
#Import Libraries
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
# Predicted values
y_pred = model.predict(x_reshaped)

# Plot
plt.scatter(x, y, color='blue', label='Actual Data')
plt.plot(x, y_pred, color='red', label='Regression Line')
plt.xlabel('Number of TV Commercials (x)')
plt.ylabel('Store Sales (y)')
plt.title('Linear Regression: TV Commercials vs. Store Sales')
plt.legend()
plt.grid(True)
plt.show()
